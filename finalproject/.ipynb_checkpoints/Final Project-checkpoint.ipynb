# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
df_ks = pd.read_csv("ks_projects.csv")

df_ks.head(10)
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
# 5  1000014025                               Monarch Espresso Bar
# 6  1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7  1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8  1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9   100004195  STUDIO IN THE SKY - A Documentary Feature Film...
#
#          category main_category currency    deadline      goal  \
# 0          Poetry    Publishing      GBP  2015-10-09    1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01   30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26   45000.0
# 3           Music         Music      USD  2012-04-16    5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29   19500.0
# 5     Restaurants          Food      USD  2016-04-01   50000.0
# 6            Food          Food      USD  2014-12-21    1000.0
# 7          Drinks          Food      USD  2016-03-17   25000.0
# 8  Product Design        Design      USD  2014-05-29  125000.0
# 9     Documentary  Film & Video      USD  2014-08-10   65000.0
#
#               launched   pledged       state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.00      failed        0      GB         0.00
# 1  2017-09-02 04:43:57   2421.00      failed       15      US       100.00
# 2  2013-01-12 00:20:50    220.00      failed        3      US       220.00
# 3  2012-03-17 03:24:11      1.00      failed        1      US         1.00
# 4  2015-07-04 08:35:03   1283.00    canceled       14      US      1283.00
# 5  2016-02-26 13:38:27  52375.00  successful      224      US     52375.00
# 6  2014-12-01 18:30:44   1205.00  successful       16      US      1205.00
# 7  2016-02-01 20:05:12    453.00      failed       40      US       453.00
# 8  2014-04-24 18:14:43   8233.00    canceled       58      US      8233.00
# 9  2014-07-11 21:55:48   6240.57    canceled       43      US      6240.57
#
#    usd_pledged_real  usd_goal_real
# 0              0.00        1533.95
# 1           2421.00       30000.00
# 2            220.00       45000.00
# 3              1.00        5000.00
# 4           1283.00       19500.00
# 5          52375.00       50000.00
# 6           1205.00        1000.00
# 7            453.00       25000.00
# 8           8233.00      125000.00
# 9           6240.57       65000.00

# %%
df_ks.groupby("main_category").nunique().count()
# Out:
# ID                  15
# name                15
# category            15
# main_category       15
# currency            15
# deadline            15
# goal                15
# launched            15
# pledged             15
# state               15
# backers             15
# country             15
# usd pledged         15
# usd_pledged_real    15
# usd_goal_real       15
# dtype: int64

# %%
df_ks.groupby("category").nunique().count()
# Out:
# ID                  159
# name                159
# category            159
# main_category       159
# currency            159
# deadline            159
# goal                159
# launched            159
# pledged             159
# state               159
# backers             159
# country             159
# usd pledged         159
# usd_pledged_real    159
# usd_goal_real       159
# dtype: int64

# %% [markdown]
# The dataset has 15 variables. Considering variables ID, name, currency, deadline date, launched date and country as self explanatory, details on other variables are as follow
#
# **Main_Category**: There are 15 main categories for the project. These main categories broadly classify projects based on topic and genre they belong to.
#
# **Category**: Main Categories are further sub divided in categories to give more general idea of the project. For example, Main Category “Technology” has 15 categories like Gadgets, Web, Apps, Software etc. There are 159 total categories.
#
# **USD_Goal_Real**: This is the goal amount which the company need to raise to start its project. The goal amount is important variable for company as if it is too high, the project may fail to raise that amount of money and be unsuccessful. If it is too low, then it may reach its goal soon and backers may not be interested to pledge more.
#
# **USD_Pledged_Real**: This is amount raised by the company through its backers. On Kickstarter, if total amount pledged is lower than goal, then the project is unsuccessful and the start-up company doesn’t receive any fund. If pledged amount is more than the goal, the company is considered successful. The variable “usd pledged” is amount of money raised in US dollars.
#
# **Backers**: These are number of people who have supported the project by pledging some amount.

# %%
df_ks = df_ks.drop("usd pledged", axis =1)

# usd pledged is similar to usd_pledged_real (or very subtle differences)

# %%
df_ks = df_ks.drop("ID", axis =1)

#ID cols is useless

# %%
df_ks = df_ks.drop("pledged", axis =1)

#this is the same as usd_pledged_real but in different currency.

# %%
df_ks.head()
# Out:
#                                                 name        category  \
# 0                    The Songs of Adelaide & Abullah          Poetry
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 2                                     Where is Hank?  Narrative Film
# 3  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 4  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#   main_category currency    deadline     goal             launched     state  \
# 0    Publishing      GBP  2015-10-09   1000.0  2015-08-11 12:12:28    failed
# 1  Film & Video      USD  2017-11-01  30000.0  2017-09-02 04:43:57    failed
# 2  Film & Video      USD  2013-02-26  45000.0  2013-01-12 00:20:50    failed
# 3         Music      USD  2012-04-16   5000.0  2012-03-17 03:24:11    failed
# 4  Film & Video      USD  2015-08-29  19500.0  2015-07-04 08:35:03  canceled
#
#    backers country  usd_pledged_real  usd_goal_real
# 0        0      GB               0.0        1533.95
# 1       15      US            2421.0       30000.00
# 2        3      US             220.0       45000.00
# 3        1      US               1.0        5000.00
# 4       14      US            1283.0       19500.00

# %%
df_ks.isnull().sum()

#checking null
# Out:
# name                4
# category            0
# main_category       0
# currency            0
# deadline            0
# goal                0
# launched            0
# state               0
# backers             0
# country             0
# usd_pledged_real    0
# usd_goal_real       0
# dtype: int64

# %%
df_ks[df_ks.name.isnull()]
# Out:
#        name        category main_category currency    deadline      goal  \
# 166851  NaN  Narrative Film  Film & Video      USD  2012-02-29  200000.0
# 307234  NaN     Video Games         Games      GBP  2013-01-06    2000.0
# 309991  NaN  Product Design        Design      USD  2016-07-18    2500.0
# 338931  NaN        Painting           Art      USD  2011-12-05   35000.0
#
#                    launched      state  backers country  usd_pledged_real  \
# 166851  2012-01-01 12:35:31     failed        1      US            100.00
# 307234  2012-12-19 23:57:48     failed       12      GB            316.05
# 309991  2016-06-18 05:01:47  suspended        0      US              0.00
# 338931  2011-11-06 23:55:55     failed        5      US            220.00
#
#         usd_goal_real
# 166851      200000.00
# 307234        3224.97
# 309991        2500.00
# 338931       35000.00

# %%
df_ks = df_ks.dropna()

# %%
df_ks.state.value_counts().plot(figsize=(20,10), kind ="bar")

# %%
df_ks["state"] = df_ks["state"].replace(["canceled","undefined","suspended"], "failed")

df_ks.state.value_counts()
# Out:
# failed        241902
# successful    133956
# live            2799
# Name: state, dtype: int64

# %%
df_ks.country.value_counts()
# Out:
# US      292624
# GB       33671
# CA       14756
# AU        7839
# DE        4171
# N,0"      3797
# FR        2939
# IT        2878
# NL        2868
# ES        2276
# SE        1757
# MX        1752
# NZ        1447
# DK        1113
# IE         811
# CH         761
# NO         708
# HK         618
# BE         617
# AT         597
# SG         555
# LU          62
# JP          40
# Name: country, dtype: int64

# %%
df_ks.currency.value_counts()
# Out:
# USD    295362
# GBP     34131
# EUR     17405
# CAD     14962
# AUD      7950
# SEK      1788
# MXN      1752
# NZD      1475
# DKK      1129
# CHF       768
# NOK       722
# HKD       618
# SGD       555
# JPY        40
# Name: currency, dtype: int64

# %%
#replacing N,0" with country based on their respective currency
#Making the assumption that the country is based on the currency indicated

# %%
df_ks[df_ks.country == 'N,0"']
# Out:
#                                                      name      category  \
# 169                         STREETFIGHTERZ WHEELIE MURICA  Film & Video
# 328                           Duncan Woods - Chameleon EP         Music
# 632             The Making of Ashley Kelley's Debut Album         Music
# 647                          Butter Side Down Debut Album         Music
# 749                               Chase Goehring debut EP         Music
# 824              Spencer Capier Instrumental Project 2015         Music
# 844     LUKAS LIGETI'S 50TH BIRTHDAY FESTIVAL: ORIGINA...         Music
# 864         The Battle For Breukelen: A Neighborhood Epic  Film & Video
# 870     "Tamboura Plays Violin" - a collection of Pop ...         Music
# 378142         Music      USD  2015-03-01   8000.0  2015-01-31 20:58:01
# 378188  Film & Video      USD  2016-05-14   2000.0  2016-04-14 01:27:27
# 378219         Music      USD  2015-12-31   5000.0  2015-12-01 00:25:06
# 378233  Film & Video      USD  2015-02-03   7500.0  2014-12-05 04:19:14
# 378303  Film & Video      CAD  2014-05-23   3000.0  2014-04-08 00:30:09
# 378434         Music      USD  2016-02-05   5000.0  2016-01-06 21:59:23
# 378585         Music      GBP  2015-10-19   2000.0  2015-09-21 22:33:18
# 378588    Publishing      EUR  2015-11-20   1600.0  2015-10-21 21:28:13
#
#              state  backers country  usd_pledged_real  usd_goal_real
# 169         failed        0    N,0"            555.00        6500.00
# 328         failed        0    N,0"           3402.08        3211.53
# 632         failed        0    N,0"           3576.00        3500.00
# 647         failed        0    N,0"           7007.80        6000.00
# 749         failed        0    N,0"           3660.38        3000.00
# 824         failed        0    N,0"           4251.14        3572.39
# 844         failed        0    N,0"           6370.00        5000.00
# 864         failed        0    N,0"           6695.00        6000.00
# 870         failed        0    N,0"           2926.00        2750.00
# 890         failed        0    N,0"           1585.00        1200.00
# 1026        failed        0    N,0"             69.00        1500.00
# 1036        failed        0    N,0"            404.18        2188.69
# 1116        failed        0    N,0"              0.00        5000.00
# 1250        failed        0    N,0"           2560.00        2000.00
# 1684        failed        0    N,0"             32.06        8550.39
# 1685        failed        0    N,0"           2079.00        2000.00
# 1718        failed        0    N,0"           2085.00        2000.00
# 1784        failed        0    N,0"            121.00        5000.00
# 1817        failed        0    N,0"            230.00        3750.00
# 1892        failed        0    N,0"           2720.00        2500.00
# 1961        failed        0    N,0"           2939.13        2804.51
# 2053        failed        0    N,0"           4101.82        3946.33
# 2201        failed        0    N,0"           8361.00        8000.00
# 2304        failed        0    N,0"             53.41        4712.83
# 2326        failed        0    N,0"              0.00        4500.00
# 2395        failed        0    N,0"              0.00        3000.00
# 2451        failed        0    N,0"           9329.00        7500.00
# 2457    successful        0    N,0"           5170.00        5000.00
# 2478        failed        0    N,0"           9660.05        9427.80
# 2606        failed        0    N,0"            168.25        2844.83
# ...            ...      ...     ...               ...            ...
# 375347      failed        0    N,0"              0.00        4599.39
# 375359      failed        0    N,0"              2.00        9000.00
# 375512      failed        0    N,0"           8025.00        8000.00
# 375765      failed        0    N,0"           8562.00        8000.00
# 375980      failed        0    N,0"              0.00        5000.00
# 376025      failed        0    N,0"            420.00        2500.00
# 376187      failed        0    N,0"            136.19        4067.35
# 376470      failed        0    N,0"           7814.00        6500.00
# 376560      failed        0    N,0"              3.14        2038.70
# 376603      failed        0    N,0"             80.00        2500.00
# 376674      failed        0    N,0"             45.00        3000.00
# 376970      failed        0    N,0"           5763.00        5500.00
# 376984      failed        0    N,0"           3435.00        3400.00
# 377043      failed        0    N,0"           8156.00        8000.00
# 377158      failed        0    N,0"           9146.00        8500.00
# 377472      failed        0    N,0"           3175.00        3000.00
# 377569      failed        0    N,0"           8061.00        8000.00
# 377638      failed        0    N,0"              0.00        4313.32
# 377640      failed        0    N,0"           6696.00        6500.00
# 377872      failed        0    N,0"           5324.59        4541.88
# 378011      failed        0    N,0"              0.00        8000.00
# 378100      failed        0    N,0"           3594.48        3594.48
# 378142      failed        0    N,0"           8582.00        8000.00
# 378188  successful        0    N,0"           2300.00        2000.00
# 378219      failed        0    N,0"           6065.26        5000.00
# 378233      failed        0    N,0"             10.00        7500.00
# 378303      failed        0    N,0"           2845.61        2752.04
# 378434      failed        0    N,0"            235.00        5000.00
# 378585      failed        0    N,0"           3273.36        3080.81
# 378588      failed        0    N,0"              0.00        1710.08
#
# [3797 rows x 12 columns]

# %%
#for each row, check country
#if country = N,0" , check currency and replace value in country
#if country != N,0", pass

# %%
country_list = {"USD":"US", 
                "GBP":"GB", 
                "CAD":"CA", 
                "EUR":"EU", 
                "AUD":"AU",
                "SEK":"SE",
                "NZD":"NZ",
                "DKK":"DK",
                "NOK":"NO",
                "CHF":"CH"}

# %%
for i in df_ks.index:
    if df_ks.loc[i,"country"]== 'N,0"':
         df_ks.loc[i,"country"] = df_ks.loc[i,"currency"]

# %%
df_ks.country.value_counts()
# Out:
# US     292624
# GB      33671
# CA      14756
# AU       7839
# DE       4171
# FR       2939
# IT       2878
# NL       2868
# USD      2738
# ES       2276
# SE       1757
# MX       1752
# NZ       1447
# DK       1113
# IE        811
# CH        761
# NO        708
# HK        618
# BE        617
# AT        597
# SG        555
# GBP       460
# CAD       206
# EUR       186
# AUD       111
# LU         62
# JP         40
# SEK        31
# NZD        28
# DKK        16
# NOK        14
# CHF         7
# Name: country, dtype: int64

# %%
df_ks = df_ks.replace({"country":country_list})

df_ks.country.nunique()
# Out:
# 23

# %%
df_ks.country.value_counts().plot(kind="bar")

# %%
# calculating the percentage of success within each country

x = df_ks[df_ks.state == "successful"].groupby("country").count()

print (x)
# Out:
#            name  category  main_category  currency  deadline    goal  \
# country
# AT          107       107            107       107       107     107
# AU         2011      2011           2011      2011      2011    2011
# BE          152       152            152       152       152     152
# CA         4137      4137           4137      4137      4137    4137
# CH          187       187            187       187       187     187
# DE          937       937            937       937       937     937
# DK          362       362            362       362       362     362
# ES          492       492            492       492       492     492
# EU            4         4              4         4         4       4
# FR          908       908            908       908       908     908
# GB        12081     12081          12081     12081     12081   12081
# HK          216       216            216       216       216     216
# IE          207       207            207       207       207     207
# IT          439       439            439       439       439     439
# JP            7         7              7         7         7       7
# LU           19        19             19        19        19      19
# MX          396       396            396       396       396     396
# NL          617       617            617       617       617     617
# NO          163       163            163       163       163     163
# NZ          448       448            448       448       448     448
# SE          509       509            509       509       509     509
# SG          178       178            178       178       178     178
# US       109379    109379         109379    109379    109379  109379
#
#          launched   state  backers  usd_pledged_real  usd_goal_real
# country
# AT            107     107      107               107            107
# AU           2011    2011     2011              2011           2011
# BE            152     152      152               152            152
# CA           4137    4137     4137              4137           4137
# CH            187     187      187               187            187
# DE            937     937      937               937            937
# DK            362     362      362               362            362
# ES            492     492      492               492            492
# EU              4       4        4                 4              4
# FR            908     908      908               908            908
# GB          12081   12081    12081             12081          12081
# HK            216     216      216               216            216
# IE            207     207      207               207            207
# IT            439     439      439               439            439
# JP              7       7        7                 7              7
# LU             19      19       19                19             19
# MX            396     396      396               396            396
# NL            617     617      617               617            617
# NO            163     163      163               163            163
# NZ            448     448      448               448            448
# SE            509     509      509               509            509
# SG            178     178      178               178            178
# US         109379  109379   109379            109379         109379

# %%
y = x.state

# %%
#calculating the percentage of successful project in each country to see if it make sense to categorize them into "others"

((y / df_ks.country.value_counts())*100).sort_values()
# Out:
# EU     2.150538
# IT    15.253648
# JP    17.500000
# AT    17.922948
# NL    21.513250
# ES    21.616872
# DE    22.464637
# NO    22.576177
# MX    22.602740
# CH    24.348958
# BE    24.635332
# AU    25.295597
# IE    25.524044
# CA    27.650047
# SE    28.467562
# NZ    30.372881
# LU    30.645161
# FR    30.894862
# DK    32.063773
# SG    32.072072
# HK    34.951456
# GB    35.395974
# US    37.032184
# dtype: float64

# %%
#I want to find out the duration of the project - taking launched date minus deadline

# %%
import datetime as dt

#df_ks["launched"] = pd.datetime(df_ks["launched"])

df_ks["launched"] = df_ks["launched"].astype('datetime64[ns]')

# df_ks["launched"] =  pd.to_datetime(df_ks["launched"], format='%Y-%b-%d :%H:%M:%S')

# %%
df_ks["launched"] = df_ks["launched"].apply(lambda x: x.date())

df_ks["launched"] = df_ks["launched"].astype('datetime64[ns]')

# %%
df_ks.head()

#checking if the time has been dropped
# Out:
#                                                 name        category  \
# 0                    The Songs of Adelaide & Abullah          Poetry
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 2                                     Where is Hank?  Narrative Film
# 3  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 4  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#   main_category currency    deadline     goal   launched   state  backers  \
# 0    Publishing      GBP  2015-10-09   1000.0 2015-08-11  failed        0
# 1  Film & Video      USD  2017-11-01  30000.0 2017-09-02  failed       15
# 2  Film & Video      USD  2013-02-26  45000.0 2013-01-12  failed        3
# 3         Music      USD  2012-04-16   5000.0 2012-03-17  failed        1
# 4  Film & Video      USD  2015-08-29  19500.0 2015-07-04  failed       14
#
#   country  usd_pledged_real  usd_goal_real
# 0      GB               0.0        1533.95
# 1      US            2421.0       30000.00
# 2      US             220.0       45000.00
# 3      US               1.0        5000.00
# 4      US            1283.0       19500.00

# %%
df_ks["deadline"]=df_ks["deadline"].astype("datetime64[ns]")

#converting deadline into datetime

# %%
df_ks.dtypes
# Out:
# name                        object
# category                    object
# main_category               object
# currency                    object
# deadline            datetime64[ns]
# goal                       float64
# launched            datetime64[ns]
# state                       object
# backers                      int64
# country                     object
# usd_pledged_real           float64
# usd_goal_real              float64
# dtype: object

# %%
df_ks["duration"] = df_ks.deadline - df_ks.launched

df_ks.duration = df_ks.duration.dt.days

#calculating duration

# %%
df_ks= df_ks[df_ks.duration < 100]

#removing outlyers that more than 1000 days

# %%
from collections import Counter

df_ks['name_count'] = df_ks['name'].apply(lambda x: len(str(x).split(' ')))

df_ks.head()

#name might not be relevant but the length of the project might affect the likeability which impact the pledged amount
# Out:
#                                                 name        category  \
# 0                    The Songs of Adelaide & Abullah          Poetry
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 2                                     Where is Hank?  Narrative Film
# 3  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 4  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#   main_category currency   deadline     goal   launched   state  backers  \
# 0    Publishing      GBP 2015-10-09   1000.0 2015-08-11  failed        0
# 1  Film & Video      USD 2017-11-01  30000.0 2017-09-02  failed       15
# 2  Film & Video      USD 2013-02-26  45000.0 2013-01-12  failed        3
# 3         Music      USD 2012-04-16   5000.0 2012-03-17  failed        1
# 4  Film & Video      USD 2015-08-29  19500.0 2015-07-04  failed       14
#
#   country  usd_pledged_real  usd_goal_real  duration  name_count
# 0      GB               0.0        1533.95        59           6
# 1      US            2421.0       30000.00        60           8
# 2      US             220.0       45000.00        45           3
# 3      US               1.0        5000.00        30           7
# 4      US            1283.0       19500.00        56           8

# %%
df_ks = df_ks.drop("name", axis =1)

#dropping name column

# %%
df_ks["deadline_day"]= df_ks["deadline"].dt.dayofweek

#0 = Monday, 1 = Tuesday ...

# %%
df_ks['deadline_year'] = pd.DatetimeIndex(df_ks['deadline']).year
df_ks['deadline_month'] = pd.DatetimeIndex(df_ks['deadline']).month

# %%
df_ks.head()
# Out:
#          category main_category currency   deadline     goal   launched  \
# 0          Poetry    Publishing      GBP 2015-10-09   1000.0 2015-08-11
# 1  Narrative Film  Film & Video      USD 2017-11-01  30000.0 2017-09-02
# 2  Narrative Film  Film & Video      USD 2013-02-26  45000.0 2013-01-12
# 3           Music         Music      USD 2012-04-16   5000.0 2012-03-17
# 4    Film & Video  Film & Video      USD 2015-08-29  19500.0 2015-07-04
#
#     state  backers country  usd_pledged_real  usd_goal_real  duration  \
# 0  failed        0      GB               0.0        1533.95        59
# 1  failed       15      US            2421.0       30000.00        60
# 2  failed        3      US             220.0       45000.00        45
# 3  failed        1      US               1.0        5000.00        30
# 4  failed       14      US            1283.0       19500.00        56
#
#    name_count  deadline_day  deadline_year  deadline_month
# 0           6             4           2015              10
# 1           8             2           2017              11
# 2           3             1           2013               2
# 3           7             0           2012               4
# 4           8             5           2015               8

# %%
df_ks = df_ks.drop("deadline", axis =1)

# %%
df_ks["launched_day"]= df_ks["launched"].dt.dayofweek

# %%
df_ks["launched_year"] = pd.DatetimeIndex(df_ks["launched"]).year
df_ks["launched_month"] = pd.DatetimeIndex(df_ks["launched"]).month

# %%
df_ks.head()
# Out:
#          category main_category currency     goal   launched   state  backers  \
# 0          Poetry    Publishing      GBP   1000.0 2015-08-11  failed        0
# 1  Narrative Film  Film & Video      USD  30000.0 2017-09-02  failed       15
# 2  Narrative Film  Film & Video      USD  45000.0 2013-01-12  failed        3
# 3           Music         Music      USD   5000.0 2012-03-17  failed        1
# 4    Film & Video  Film & Video      USD  19500.0 2015-07-04  failed       14
#
#   country  usd_pledged_real  usd_goal_real  duration  name_count  \
# 0      GB               0.0        1533.95        59           6
# 1      US            2421.0       30000.00        60           8
# 2      US             220.0       45000.00        45           3
# 3      US               1.0        5000.00        30           7
# 4      US            1283.0       19500.00        56           8
#
#    deadline_day  deadline_year  deadline_month  launched_day  launched_year  \
# 0             4           2015              10             1           2015
# 1             2           2017              11             5           2017
# 2             1           2013               2             5           2013
# 3             0           2012               4             5           2012
# 4             5           2015               8             5           2015
#
#    launched_month
# 0               8
# 1               9
# 2               1
# 3               3
# 4               7

# %%
df_ks = df_ks.drop("launched", axis =1)

# %%
import seaborn as sns

fig, ax =plt.subplots(figsize=(10, 8))
ks_corr = df_ks.corr()
sns.heatmap(ks_corr, mask=np.zeros_like(ks_corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %%
#get_dummies

# %%
# df2 = df_ks.drop(["name","currency","deadline","launched","backers"], axis =1)

# %%
# import seaborn as sns

# sns.pairplot(df2)

# %%
#Determine the most relevant 5 variables

# %% [markdown]
# What are the common factors that would make a kickstarter project successful? Two class categories
